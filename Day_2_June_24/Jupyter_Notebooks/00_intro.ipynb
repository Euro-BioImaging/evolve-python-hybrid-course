# %% [markdown]
# # Intro Course Day 2

# %% [markdown]
# ## Today
#
# - Day 1 - June 23rd: Intro to Jupyter notebooks and Python, introduction to loading images and microscopy metadata, basics of visualisation
# - **Day 2 - June 24th: Practical image processing with Python: segmentation, denoising, morphology and automation of analysis pipelines.**
# - Day 3 - June 25th: Novel strategies for segmentation: Machine learning + use of pre-trained models from the Bioimage Model Zoo.

# %% [markdown]
# ## Recap day 1
#
# - Introduction to Python and Jupyter
#   - Python basics
#   - importing and using different packages
#   - installing Python environments
# - Loading / viewing microscopy images and metadata
# - Example bioimage analysis applications
#   - image processing
#   - segmentation
#   - quantification

# %% [markdown]
# ## Day 2 (today): Classical image processing and analysis

# %% [markdown]
# ### Goals
# - Learn basic concepts of image processing
# - Learn how to apply these using Python and Jupyter
# - Build an example image processing pipeline

# %% [markdown]
# ## Example dataset: Cell Atlas / Human Protein Atlas
#
# Examples of proteins (green) localising to each annotated structure in the representative set of human cell lines used in the Cell Atlas. Microtubules are marked with an antibody against tubulin (red); the nucleus is counterstained with DAPI (blue).
#
# <img src="illustrations/cell_atlas_overview.png" alt="drawing" width="80%" class="center"/>
#
# Adapted from Thul PJ et al., A subcellular map of the human proteome. **Science**. (2017) DOI: 10.1126/science.aal3321

# %% [markdown]
# ## Example image processing pipeline
#
# Aim: Quantify signal accumulation within the nuclear membrane
#
# <img src="illustrations/example_workflow_aim.png" alt="drawing" width="80%" class="center"/>
#
# Workflow and slide taken from Anna Klemm's course at NEUBIAS Academy@Home 2020.

# %% [markdown]
# ## Acknowledgements
#
# This course reuses materials assembled together from courses by
# - Guillaume Witz: https://github.com/guiwitz/PyImageCourse_beginner
# - Anna Klemm: https://github.com/ahklemm/ImageJMacro_Introduction
# - Pete Bankhead: https://bioimagebook.github.io/
#
# The [original material](https://iah-public.pages.pasteur.fr/20241008_remote_python_bioimage_analysis_course_day2/README.html) was developed by Marie Anselmet, Marvin Albert, Jean-Yves Tinevez (@ Image Analysis Hub @ Institut Pasteur)

# %% [markdown]
# ## Day overview
#
# ### Morning: Image processing
#   - Thresholding
#   - Filtering
#   - Segmentation
#
# ### Afternoon: Image analysis
#   - Feature extraction
#   - Building analysis pipelines
#   - Data Analysis

# %% [markdown]
# ## Let's start
