# %% [markdown]
# # Exercise 1: Image thresholding

# %% [markdown]
# 1. Import the relevant packages: numpy, matplotlib and skimage

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage

# %% [markdown]
# 2. Import the image from this url address: https://cildata.crbs.ucsd.edu/media/images/13585/13585.tif.

# %%
image = skimage.io.imread('https://cildata.crbs.ucsd.edu/media/images/13585/13585.tif')
image.shape

# %% [markdown]
# 3. Create a new variable called ```image_green``` that contains only the second channel by slicing/indexing the array

# %%
image_green = image[:, :, 1]

# %% [markdown]
# 4. Plot this image

# %%
plt.imshow(image_green, cmap='grey')
plt.axis('off')
plt.show()

# %% [markdown]
# 5. Plot a histogram of the image

# %%
plt.hist(image_green.flatten(), bins=50, range=(0, 256), density=True); # tip: use semicolon to suppress output

# %% [markdown]
# 6. Try to determine an appropriate manual threshold to recover the large structures in the image and create a binary image using this threshold. Compare the binary image with the original image using `stackview.switch` (the images to be compared need to be passed to the function as a list).

# %%
threshold = 50

image_green_thresholded = image_green > threshold

import stackview
stackview.switch([image_green, image_green_thresholded])

# %% [markdown]
# 7. Use the function `skimage.filters.try_all_threshold` to compare different automated thresholding methods.

# %%
# nice function to try all thresholding methods:

skimage.filters.try_all_threshold(image_green, figsize=(10, 8), verbose=False);

# %% [markdown]
# 8. Choose one of the thresholding methods and apply it. You can find the corresponding function in the [`scikit-image` documentation](http://scikit-image.org/docs/dev/api/skimage.filters.html) (methods for determining thresholds start with `threshold_`). Compare the binary image with the original image using `stackview.switch`.

# %%
threshold = skimage.filters.threshold_yen(image_green)

print('The threshold was determined as:', threshold)

image_green_thresholded = image_green > threshold

stackview.switch([image_green, image_green_thresholded])
